# %%
import sys
import os

current_directory = os.getcwd()        
parent_directory = os.path.dirname(current_directory)
sys.path.append(parent_directory)


from preprocess.graph import graph_topology_5
from preprocess.BaselinePrerocess import baseline_process, baseline_process_for_gate_predictor
from preprocess.GraphTransformerPrerocess import graph_water_transformer_cov_process_for_gate_predictor
from baselines.rnn import rnn_gate_generator_1
from models.graph_water_transformer_cov import graph_water_transformer_cov_gate_predictor

from losses.loss import gate_loss, water_level_threshold
from tensorflow.keras.models import load_model
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
import time
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from postprocess.threshold import flood_threshold, drought_threshold, flood_threshold_t1, drought_threshold_t1
from spektral.layers import GCNConv
# Out:
# 2023-08-12 17:20:14.115256: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-12 17:20:15.471996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
n_hours = 72
K = 24 
masked_value = 1e-10
split_1 = 0.8
split_2 = 0.9
sigma2 = 0.1
epsilon = 0.5

# %%
train_X_mask, val_X_mask, test_X_mask, \
train_ws_y, val_ws_y, test_ws_y, \
scaler, ws_scaler = baseline_process(n_hours, K, masked_value, split_1, split_2)
# Out:
# Index(['WS_S1', 'WS_S4', 'FLOW_S25A', 'GATE_S25A', 'HWS_S25A', 'TWS_S25A',
#        'FLOW_S25B', 'GATE_S25B', 'GATE_S25B2', 'HWS_S25B', 'TWS_S25B',
#        'PUMP_S25B', 'FLOW_S26', 'GATE_S26_1', 'GATE_S26_2', 'HWS_S26',
#        'TWS_S26', 'PUMP_S26', 'MEAN_RAIN'],
#       dtype='object')

# %%
train_cov, val_cov, test_cov, \
train_tws_reshape, val_tws_reshape, test_tws_reshape, \
train_gate_pump_y, val_gate_pump_y, test_gate_pump_y, \
train_ws_y, val_ws_y, test_ws_y, \
scaler, ws_scaler, gate_scalar = graph_water_transformer_cov_process_for_gate_predictor(n_hours, K, masked_value, split_1, split_2)
# Out:
# Index(['WS_S1', 'WS_S4', 'FLOW_S25A', 'GATE_S25A', 'HWS_S25A', 'TWS_S25A',
#        'FLOW_S25B', 'GATE_S25B', 'GATE_S25B2', 'HWS_S25B', 'TWS_S25B',
#        'PUMP_S25B', 'FLOW_S26', 'GATE_S26_1', 'GATE_S26_2', 'HWS_S26',
#        'TWS_S26', 'PUMP_S26', 'MEAN_RAIN'],
#       dtype='object')
# train_tws/val_tws/test_tws: (77069, 5, 72) (9634, 5, 72) (19268, 5, 72)
#  train_cov/val_cov/test_cov: (77069, 96, 12) (9634, 96, 12) (19268, 96, 12)
#  train_ws_y/val_ws_y/test_ws_y: (77069, 96) (9634, 96) (19268, 96)
#   train_gate_pump_y/val_gate_pump_y/test_gate_pump_y: (77069, 24, 7) (9634, 24, 7) (19268, 24, 7)

# %% [markdown]
# ### Graph topology

# %%
train_adj_mat, val_adj_mat, test_adj_mat = graph_topology_5(n_hours, K, sigma2, epsilon, len(train_ws_y), len(val_ws_y), len(test_ws_y))
# Out:
# node_indices: [0 0 0 0 1 1 2 2 3 3 4 4]
# neighbor_indices: [1 2 3 4 0 2 0 1 0 4 0 3]
# number of nodes: 5, number of edges: 12

# %% [markdown]
# ### Model

# %% [markdown]
# #### Gate & pump predictor

# %%
# ===== model parameters ======
input_shape = train_X_mask.shape[1:]
rnn_unit = 64
l1_reg = 1e-5
l2_reg = 1e-5
dropout = 0.2
gate_min =0 
gate_max = 1


learning_rate = 1e-3
decay_steps = 10000
decay_rate = 0.9
PATIENCE = 100
EPOCHS = 700
BATCH = 512
input_shape = train_X_mask.shape[1:]

# %%
gate_predictor = rnn_gate_generator_1(input_shape=input_shape,
                                      rnn_unit=rnn_unit,
                                      l1_reg=l1_reg, 
                                      l2_reg=l2_reg, 
                                      dropout=dropout,
                                      masked_value=masked_value,
                                      gate_min=gate_min,
                                      gate_max=gate_max
                                     )


gate_predictor._name = "gate_predictor"
gate_predictor.summary()
# Out:
# Model: "gate_predictor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 16)]          0
#
#  masking (Masking)           (None, 96, 16)            0
#
#  simple_rnn (SimpleRNN)      (None, 96, 64)            5184
#
#  dropout (Dropout)           (None, 96, 64)            0
#
#  max_pooling1d (MaxPooling1  (None, 24, 64)            0
#  D)
#
#  dense (Dense)               (None, 24, 7)             455
#
#  tf.math.maximum (TFOpLambd  (None, 24, 7)             0
#  a)
#
#  tf.math.minimum (TFOpLambd  (None, 24, 7)             0
#  a)
#
# =================================================================
# Total params: 5639 (22.03 KB)
# Trainable params: 5639 (22.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-08-12 17:20:28.358553: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10402 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:05:00.0, compute capability: 6.1

# %%
gate_predictor.compile(optimizer='adam', loss='mse')

# %% [markdown]
# #### water stage predictor

# %%
ws_predictor = load_model('../saved_models/WaLeF_gtn_p.h5', custom_objects={'GCNConv': GCNConv})

for layer in ws_predictor.layers:
    layer.trainable = False

ws_predictor._name = 'ws_predictor'    
# ws_predictor.summary()
# Out:
# WARNING:tensorflow:Layer LSTM will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# #### Combine gate_predictor and trained ws_predictor

# %%
inputs_feat = Input(shape=(96, 16), name='inputs_feat')
inputs_tws = Input(shape=(5, 72), name='input_tws')
inputs_adj = Input(shape=(5, 5), name='input_adj')

# ================ gate_predictor ================
gate_predictor_output = gate_predictor(inputs_feat)  # 24*7


# ============  future inputs with replaced gate & pump prediction ============
replaced_future_gate_pump = layers.Concatenate(axis=-1)([inputs_feat[:, n_hours:, :2], 
                                                         gate_predictor_output, 
                                                         inputs_feat[:, n_hours:, 9:]
                                                        ]
                                                       )

# ============ original past inputs + future inputs with replaced gate & pump prediction ============
merged_inputs = layers.Concatenate(axis=1)([inputs_feat[:, :n_hours, :], replaced_future_gate_pump])
merged_inputs_cov = merged_inputs[:, :, :12]

ws_predictor_output = ws_predictor([merged_inputs_cov, inputs_tws, inputs_adj])

filda = Model(inputs=[inputs_feat, inputs_tws, inputs_adj], outputs=[gate_predictor_output, ws_predictor_output], name='filda')
# filda.summary()

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
                                                          decay_steps=decay_steps,
                                                          decay_rate=decay_rate)

filda.compile(optimizer=Adam(learning_rate=lr_schedule),
             loss=[gate_loss, water_level_threshold], 
             loss_weights=[0.0, 2.0]
            )


es = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=100)
mc = ModelCheckpoint('../saved_models/rnn_gtnp_1.h5'.format(n_hours, K),
                     monitor='val_ws_predictor_loss',
                     mode='min',
                     verbose=2, 
                     custom_objects={'gate_loss':gate_loss, 'water_level_threshold':water_level_threshold}, 
                     save_best_only=True)


history = filda.fit([train_X_mask, train_tws_reshape, train_adj_mat], [train_gate_pump_y, train_ws_y],
                   validation_data=([val_X_mask, val_tws_reshape, val_adj_mat], [val_gate_pump_y, val_ws_y]),
                   batch_size=BATCH, 
                   epochs=EPOCHS, 
                   verbose=2, 
                   callbacks=[es, mc],
                   shuffle=True,

                  )


plt.rcParams["figure.figsize"] = (8, 6)
plt.plot(history.history['ws_predictor_loss'], label='train')
plt.plot(history.history['val_ws_predictor_loss'], label='val')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.legend(fontsize=14)
plt.title("Training loss vs Testing loss", fontsize=18)
# plt.savefig('graph/rnn_loss.png', dpi=300)
plt.show()
# Out:
# Epoch 1/700
# 2023-08-10 16:54:06.315206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-08-10 16:54:07.648358: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe351bef9e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-10 16:54:07.648414: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-08-10 16:54:07.658586: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-10 16:54:08.008123: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_ws_predictor_loss improved from inf to 3.67524, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 28s - loss: 0.5001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2471 - val_loss: 7.3559 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 3.6752 - 28s/epoch - 183ms/step
# Epoch 2/700
# /aul/homes/jshi008/miniconda3/envs/tf213/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_ws_predictor_loss improved from 3.67524 to 3.53356, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 18s - loss: 0.4808 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2377 - val_loss: 7.0723 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 3.5336 - 18s/epoch - 117ms/step
# Epoch 3/700
#
# Epoch 3: val_ws_predictor_loss improved from 3.53356 to 2.94655, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 18s - loss: 0.4692 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2320 - val_loss: 5.8982 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 2.9465 - 18s/epoch - 117ms/step
# Epoch 4/700
#
# Epoch 4: val_ws_predictor_loss improved from 2.94655 to 2.56042, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4626 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2288 - val_loss: 5.1259 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 2.5604 - 17s/epoch - 116ms/step
# Epoch 5/700
#
# Epoch 5: val_ws_predictor_loss did not improve from 2.56042
# 151/151 - 17s - loss: 0.4582 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2266 - val_loss: 5.3677 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 2.6814 - 17s/epoch - 114ms/step
# Epoch 6/700
#
# Epoch 6: val_ws_predictor_loss improved from 2.56042 to 2.41014, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4515 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2232 - val_loss: 4.8253 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 2.4101 - 17s/epoch - 115ms/step
# Epoch 7/700
#
# Epoch 7: val_ws_predictor_loss improved from 2.41014 to 2.31373, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4443 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2196 - val_loss: 4.6325 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 2.3137 - 17s/epoch - 114ms/step
# Epoch 8/700
#
# Epoch 8: val_ws_predictor_loss improved from 2.31373 to 1.92884, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4385 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2167 - val_loss: 3.8628 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.9288 - 17s/epoch - 116ms/step
# Epoch 9/700
#
# Epoch 9: val_ws_predictor_loss improved from 1.92884 to 1.86889, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4309 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2129 - val_loss: 3.7429 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.8689 - 17s/epoch - 114ms/step
# Epoch 10/700
#
# Epoch 10: val_ws_predictor_loss improved from 1.86889 to 1.75861, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4267 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2108 - val_loss: 3.5224 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7586 - 17s/epoch - 115ms/step
# Epoch 11/700
#
# Epoch 11: val_ws_predictor_loss did not improve from 1.75861
# 151/151 - 17s - loss: 0.4240 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2094 - val_loss: 3.5418 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7683 - 17s/epoch - 116ms/step
# Epoch 12/700
#
# Epoch 12: val_ws_predictor_loss did not improve from 1.75861
# 151/151 - 17s - loss: 0.4214 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2081 - val_loss: 3.5273 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7611 - 17s/epoch - 113ms/step
# Epoch 13/700
#
# Epoch 13: val_ws_predictor_loss improved from 1.75861 to 1.70805, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4190 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2069 - val_loss: 3.4212 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7081 - 17s/epoch - 116ms/step
# Epoch 14/700
#
# Epoch 14: val_ws_predictor_loss did not improve from 1.70805
# 151/151 - 17s - loss: 0.4179 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2064 - val_loss: 3.5751 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7850 - 17s/epoch - 112ms/step
# Epoch 15/700
#
# Epoch 15: val_ws_predictor_loss did not improve from 1.70805
# 151/151 - 17s - loss: 0.4175 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2062 - val_loss: 3.5020 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7484 - 17s/epoch - 113ms/step
# Epoch 16/700
#
# Epoch 16: val_ws_predictor_loss improved from 1.70805 to 1.68363, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4165 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2057 - val_loss: 3.3724 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6836 - 17s/epoch - 115ms/step
# Epoch 17/700
#
# Epoch 17: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 18s - loss: 0.4160 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2054 - val_loss: 3.5463 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7706 - 18s/epoch - 116ms/step
# Epoch 18/700
#
# Epoch 18: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4150 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2050 - val_loss: 3.3962 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6955 - 17s/epoch - 114ms/step
# Epoch 19/700
#
# Epoch 19: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4153 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2051 - val_loss: 3.4378 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7163 - 17s/epoch - 114ms/step
# Epoch 20/700
#
# Epoch 20: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 18s - loss: 0.4147 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2048 - val_loss: 3.3850 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6900 - 18s/epoch - 118ms/step
# Epoch 21/700
#
# Epoch 21: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4138 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2043 - val_loss: 3.4381 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7165 - 17s/epoch - 116ms/step
# Epoch 22/700
#
# Epoch 22: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4136 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2043 - val_loss: 3.4365 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7157 - 17s/epoch - 115ms/step
# Epoch 23/700
#
# Epoch 23: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4145 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2047 - val_loss: 3.4265 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7107 - 17s/epoch - 115ms/step
# Epoch 24/700
#
# Epoch 24: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 18s - loss: 0.4125 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2037 - val_loss: 3.3965 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6957 - 18s/epoch - 116ms/step
# Epoch 25/700
#
# Epoch 25: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4125 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2037 - val_loss: 3.4131 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7040 - 17s/epoch - 114ms/step
# Epoch 26/700
#
# Epoch 26: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 18s - loss: 0.4119 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2034 - val_loss: 3.4974 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7462 - 18s/epoch - 116ms/step
# Epoch 27/700
#
# Epoch 27: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4113 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2031 - val_loss: 3.4726 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7338 - 17s/epoch - 114ms/step
# Epoch 28/700
#
# Epoch 28: val_ws_predictor_loss did not improve from 1.68363
# 151/151 - 17s - loss: 0.4102 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2026 - val_loss: 3.5277 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7613 - 17s/epoch - 115ms/step
# Epoch 29/700
#
# Epoch 29: val_ws_predictor_loss improved from 1.68363 to 1.68132, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4099 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2024 - val_loss: 3.3677 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6813 - 17s/epoch - 113ms/step
# Epoch 30/700
#
# Epoch 30: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4094 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2022 - val_loss: 3.3821 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6885 - 17s/epoch - 115ms/step
# Epoch 31/700
#
# Epoch 31: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4089 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2019 - val_loss: 3.3700 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6825 - 17s/epoch - 116ms/step
# Epoch 32/700
#
# Epoch 32: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 18s - loss: 0.4091 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2021 - val_loss: 3.4782 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7366 - 18s/epoch - 118ms/step
# Epoch 33/700
#
# Epoch 33: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4084 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2017 - val_loss: 3.4223 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7086 - 17s/epoch - 116ms/step
# Epoch 34/700
#
# Epoch 34: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4082 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2016 - val_loss: 3.4570 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7260 - 17s/epoch - 113ms/step
# Epoch 35/700
#
# Epoch 35: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4083 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2016 - val_loss: 3.4429 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7190 - 17s/epoch - 114ms/step
# Epoch 36/700
#
# Epoch 36: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4082 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2016 - val_loss: 3.3714 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6832 - 17s/epoch - 116ms/step
# Epoch 37/700
#
# Epoch 37: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4076 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2013 - val_loss: 3.3707 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6828 - 17s/epoch - 114ms/step
# Epoch 38/700
#
# Epoch 38: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 17s - loss: 0.4073 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2012 - val_loss: 3.5306 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7628 - 17s/epoch - 115ms/step
# Epoch 39/700
#
# Epoch 39: val_ws_predictor_loss did not improve from 1.68132
# 151/151 - 18s - loss: 0.4078 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2014 - val_loss: 3.3967 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6959 - 18s/epoch - 120ms/step
# Epoch 40/700
#
# Epoch 40: val_ws_predictor_loss improved from 1.68132 to 1.66554, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 18s - loss: 0.4073 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2012 - val_loss: 3.3360 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6655 - 18s/epoch - 117ms/step
# Epoch 41/700
#
# Epoch 41: val_ws_predictor_loss did not improve from 1.66554
# 151/151 - 18s - loss: 0.4074 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2012 - val_loss: 3.3783 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6867 - 18s/epoch - 117ms/step
# Epoch 42/700
#
# Epoch 42: val_ws_predictor_loss did not improve from 1.66554
# 151/151 - 17s - loss: 0.4069 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2010 - val_loss: 3.3660 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6805 - 17s/epoch - 116ms/step
# Epoch 43/700
#
# Epoch 43: val_ws_predictor_loss improved from 1.66554 to 1.64668, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4065 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2007 - val_loss: 3.2983 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6467 - 17s/epoch - 115ms/step
# Epoch 44/700
#
# Epoch 44: val_ws_predictor_loss did not improve from 1.64668
# 151/151 - 17s - loss: 0.4062 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2006 - val_loss: 3.4296 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.7123 - 17s/epoch - 114ms/step
# Epoch 45/700
#
# Epoch 45: val_ws_predictor_loss did not improve from 1.64668
# 151/151 - 17s - loss: 0.4064 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2007 - val_loss: 3.3838 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6894 - 17s/epoch - 113ms/step
# Epoch 46/700
#
# Epoch 46: val_ws_predictor_loss did not improve from 1.64668
# 151/151 - 18s - loss: 0.4058 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2004 - val_loss: 3.3225 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6588 - 18s/epoch - 116ms/step
# Epoch 47/700
#
# Epoch 47: val_ws_predictor_loss did not improve from 1.64668
# 151/151 - 17s - loss: 0.4060 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2005 - val_loss: 3.3428 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6689 - 17s/epoch - 113ms/step
# Epoch 48/700
#
# Epoch 48: val_ws_predictor_loss improved from 1.64668 to 1.64031, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4054 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2002 - val_loss: 3.2856 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6403 - 17s/epoch - 114ms/step
# Epoch 49/700
#
# Epoch 49: val_ws_predictor_loss did not improve from 1.64031
# 151/151 - 17s - loss: 0.4053 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2002 - val_loss: 3.3669 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6810 - 17s/epoch - 113ms/step
# Epoch 50/700
#
# Epoch 50: val_ws_predictor_loss did not improve from 1.64031
# 151/151 - 17s - loss: 0.4049 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2000 - val_loss: 3.3323 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6637 - 17s/epoch - 114ms/step
# Epoch 51/700
#
# Epoch 51: val_ws_predictor_loss improved from 1.64031 to 1.63521, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 18s - loss: 0.4048 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1999 - val_loss: 3.2753 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6352 - 18s/epoch - 117ms/step
# Epoch 52/700
#
# Epoch 52: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4049 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2000 - val_loss: 3.3583 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6767 - 17s/epoch - 116ms/step
# Epoch 53/700
#
# Epoch 53: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4045 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1998 - val_loss: 3.3086 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6519 - 17s/epoch - 115ms/step
# Epoch 54/700
#
# Epoch 54: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4039 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1995 - val_loss: 3.3172 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6561 - 17s/epoch - 115ms/step
# Epoch 55/700
#
# Epoch 55: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4050 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.2001 - val_loss: 3.3000 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6476 - 17s/epoch - 113ms/step
# Epoch 56/700
#
# Epoch 56: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4040 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1995 - val_loss: 3.3389 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6670 - 17s/epoch - 114ms/step
# Epoch 57/700
#
# Epoch 57: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4038 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1994 - val_loss: 3.3748 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6850 - 17s/epoch - 114ms/step
# Epoch 58/700
#
# Epoch 58: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 18s - loss: 0.4034 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1993 - val_loss: 3.3377 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6664 - 18s/epoch - 118ms/step
# Epoch 59/700
#
# Epoch 59: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4038 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1994 - val_loss: 3.3102 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6527 - 17s/epoch - 116ms/step
# Epoch 60/700
#
# Epoch 60: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4034 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1992 - val_loss: 3.3315 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6633 - 17s/epoch - 113ms/step
# Epoch 61/700
#
# Epoch 61: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4035 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1993 - val_loss: 3.2896 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6424 - 17s/epoch - 113ms/step
# Epoch 62/700
#
# Epoch 62: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 18s - loss: 0.4028 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1990 - val_loss: 3.3849 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6900 - 18s/epoch - 116ms/step
# Epoch 63/700
#
# Epoch 63: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 18s - loss: 0.4032 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1992 - val_loss: 3.3715 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6833 - 18s/epoch - 117ms/step
# Epoch 64/700
#
# Epoch 64: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 18s - loss: 0.4037 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1994 - val_loss: 3.3575 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6763 - 18s/epoch - 116ms/step
# Epoch 65/700
#
# Epoch 65: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 17s - loss: 0.4032 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1992 - val_loss: 3.2981 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6466 - 17s/epoch - 115ms/step
# Epoch 66/700
#
# Epoch 66: val_ws_predictor_loss did not improve from 1.63521
# 151/151 - 18s - loss: 0.4034 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1993 - val_loss: 3.3107 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6529 - 18s/epoch - 116ms/step
# Epoch 67/700
#
# Epoch 67: val_ws_predictor_loss improved from 1.63521 to 1.61402, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4031 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1992 - val_loss: 3.2329 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6140 - 17s/epoch - 115ms/step
# Epoch 68/700
#
# Epoch 68: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4027 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1989 - val_loss: 3.2954 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6453 - 17s/epoch - 114ms/step
# Epoch 69/700
#
# Epoch 69: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4028 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1990 - val_loss: 3.3845 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6898 - 17s/epoch - 115ms/step
# Epoch 70/700
#
# Epoch 70: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4024 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1988 - val_loss: 3.3059 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6505 - 17s/epoch - 116ms/step
# Epoch 71/700
#
# Epoch 71: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4024 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1988 - val_loss: 3.3359 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6655 - 17s/epoch - 115ms/step
# Epoch 72/700
#
# Epoch 72: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4020 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1986 - val_loss: 3.3101 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6527 - 17s/epoch - 115ms/step
# Epoch 73/700
#
# Epoch 73: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4031 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1992 - val_loss: 3.3892 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6922 - 17s/epoch - 114ms/step
# Epoch 74/700
#
# Epoch 74: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4022 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1987 - val_loss: 3.2631 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6292 - 17s/epoch - 114ms/step
# Epoch 75/700
#
# Epoch 75: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4022 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1987 - val_loss: 3.2853 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6403 - 17s/epoch - 115ms/step
# Epoch 76/700
#
# Epoch 76: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 18s - loss: 0.4026 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1989 - val_loss: 3.2526 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6239 - 18s/epoch - 118ms/step
# Epoch 77/700
#
# Epoch 77: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4034 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1993 - val_loss: 3.2600 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6276 - 17s/epoch - 115ms/step
# Epoch 78/700
#
# Epoch 78: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4028 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1990 - val_loss: 3.2441 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6196 - 17s/epoch - 113ms/step
# Epoch 79/700
#
# Epoch 79: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 18s - loss: 0.4020 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1986 - val_loss: 3.2691 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6322 - 18s/epoch - 117ms/step
# Epoch 80/700
#
# Epoch 80: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4022 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1987 - val_loss: 3.2359 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6156 - 17s/epoch - 116ms/step
# Epoch 81/700
#
# Epoch 81: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 18s - loss: 0.4020 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1986 - val_loss: 3.2569 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6261 - 18s/epoch - 116ms/step
# Epoch 82/700
#
# Epoch 82: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4018 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1985 - val_loss: 3.2362 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6157 - 17s/epoch - 116ms/step
# Epoch 83/700
#
# Epoch 83: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4019 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1986 - val_loss: 3.2465 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6209 - 17s/epoch - 114ms/step
# Epoch 84/700
#
# Epoch 84: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4023 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1988 - val_loss: 3.2680 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6316 - 17s/epoch - 115ms/step
# Epoch 85/700
#
# Epoch 85: val_ws_predictor_loss did not improve from 1.61402
# 151/151 - 17s - loss: 0.4017 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1985 - val_loss: 3.3221 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6587 - 17s/epoch - 115ms/step
# Epoch 86/700
#
# Epoch 86: val_ws_predictor_loss improved from 1.61402 to 1.60682, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 17s - loss: 0.4016 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2184 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6068 - 17s/epoch - 116ms/step
# Epoch 87/700
#
# Epoch 87: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4013 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1983 - val_loss: 3.2870 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6412 - 17s/epoch - 114ms/step
# Epoch 88/700
#
# Epoch 88: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4010 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.2307 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6130 - 17s/epoch - 115ms/step
# Epoch 89/700
#
# Epoch 89: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4015 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2242 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6098 - 17s/epoch - 115ms/step
# Epoch 90/700
#
# Epoch 90: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4010 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.3282 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6618 - 17s/epoch - 114ms/step
# Epoch 91/700
#
# Epoch 91: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4024 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1989 - val_loss: 3.2512 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6233 - 17s/epoch - 115ms/step
# Epoch 92/700
#
# Epoch 92: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 18s - loss: 0.4019 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1986 - val_loss: 3.2696 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6325 - 18s/epoch - 116ms/step
# Epoch 93/700
#
# Epoch 93: val_ws_predictor_loss did not improve from 1.60682
# 151/151 - 17s - loss: 0.4012 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1983 - val_loss: 3.2697 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6325 - 17s/epoch - 115ms/step
# Epoch 94/700
#
# Epoch 94: val_ws_predictor_loss improved from 1.60682 to 1.57512, saving model to ../saved_models/rnn_gtnp_1.h5
# 151/151 - 18s - loss: 0.4015 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.1549 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.5751 - 18s/epoch - 116ms/step
# Epoch 95/700
#
# Epoch 95: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4012 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1983 - val_loss: 3.2361 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6157 - 18s/epoch - 117ms/step
# Epoch 96/700
#
# Epoch 96: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4008 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2994 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6474 - 18s/epoch - 117ms/step
# Epoch 97/700
#
# Epoch 97: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4015 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2511 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6232 - 17s/epoch - 115ms/step
# Epoch 98/700
#
# Epoch 98: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4022 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1988 - val_loss: 3.2634 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6294 - 18s/epoch - 116ms/step
# Epoch 99/700
#
# Epoch 99: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4008 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2775 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6364 - 18s/epoch - 118ms/step
# Epoch 100/700
#
# Epoch 100: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4014 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2648 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6301 - 17s/epoch - 114ms/step
# Epoch 101/700
#
# Epoch 101: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4010 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.3076 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6515 - 17s/epoch - 115ms/step
# Epoch 102/700
#
# Epoch 102: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4007 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2403 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6178 - 17s/epoch - 116ms/step
# Epoch 103/700
#
# Epoch 103: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4010 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.2634 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6294 - 18s/epoch - 116ms/step
# Epoch 104/700
#
# Epoch 104: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4005 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2448 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6201 - 17s/epoch - 115ms/step
# Epoch 105/700
#
# Epoch 105: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4024 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1989 - val_loss: 3.2527 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6241 - 17s/epoch - 115ms/step
# Epoch 106/700
#
# Epoch 106: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4008 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2770 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6362 - 18s/epoch - 116ms/step
# Epoch 107/700
#
# Epoch 107: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2561 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6258 - 18s/epoch - 116ms/step
# Epoch 108/700
#
# Epoch 108: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4009 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2534 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6244 - 17s/epoch - 115ms/step
# Epoch 109/700
#
# Epoch 109: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4011 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1983 - val_loss: 3.2407 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6181 - 17s/epoch - 114ms/step
# Epoch 110/700
#
# Epoch 110: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4003 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2427 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6191 - 18s/epoch - 117ms/step
# Epoch 111/700
#
# Epoch 111: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.3632 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6794 - 18s/epoch - 118ms/step
# Epoch 112/700
#
# Epoch 112: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4012 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1983 - val_loss: 3.2621 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6288 - 17s/epoch - 116ms/step
# Epoch 113/700
#
# Epoch 113: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4005 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2083 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6019 - 17s/epoch - 115ms/step
# Epoch 114/700
#
# Epoch 114: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2198 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6076 - 17s/epoch - 114ms/step
# Epoch 115/700
#
# Epoch 115: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4014 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2227 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6091 - 18s/epoch - 117ms/step
# Epoch 116/700
#
# Epoch 116: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4007 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2443 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6199 - 17s/epoch - 114ms/step
# Epoch 117/700
#
# Epoch 117: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2934 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6444 - 17s/epoch - 113ms/step
# Epoch 118/700
#
# Epoch 118: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4007 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2311 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6133 - 17s/epoch - 114ms/step
# Epoch 119/700
#
# Epoch 119: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2553 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6254 - 18s/epoch - 116ms/step
# Epoch 120/700
#
# Epoch 120: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2348 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6151 - 17s/epoch - 114ms/step
# Epoch 121/700
#
# Epoch 121: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4002 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2516 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6236 - 18s/epoch - 117ms/step
# Epoch 122/700
#
# Epoch 122: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4003 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2439 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6197 - 18s/epoch - 116ms/step
# Epoch 123/700
#
# Epoch 123: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2184 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6070 - 17s/epoch - 114ms/step
# Epoch 124/700
#
# Epoch 124: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4007 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1981 - val_loss: 3.2583 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6269 - 18s/epoch - 116ms/step
# Epoch 125/700
#
# Epoch 125: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4005 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2521 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6238 - 17s/epoch - 114ms/step
# Epoch 126/700
#
# Epoch 126: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2087 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6021 - 17s/epoch - 114ms/step
# Epoch 127/700
#
# Epoch 127: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2192 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6074 - 17s/epoch - 115ms/step
# Epoch 128/700
#
# Epoch 128: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2427 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6191 - 17s/epoch - 114ms/step
# Epoch 129/700
#
# Epoch 129: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4013 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1984 - val_loss: 3.2307 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6131 - 17s/epoch - 115ms/step
# Epoch 130/700
#
# Epoch 130: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4008 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.2411 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6183 - 17s/epoch - 111ms/step
# Epoch 131/700
#
# Epoch 131: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3997 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2149 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6052 - 17s/epoch - 115ms/step
# Epoch 132/700
#
# Epoch 132: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2610 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6283 - 17s/epoch - 114ms/step
# Epoch 133/700
#
# Epoch 133: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2661 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6308 - 18s/epoch - 117ms/step
# Epoch 134/700
#
# Epoch 134: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3997 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2505 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6230 - 18s/epoch - 117ms/step
# Epoch 135/700
#
# Epoch 135: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2508 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6232 - 17s/epoch - 116ms/step
# Epoch 136/700
#
# Epoch 136: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3995 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1975 - val_loss: 3.2728 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6342 - 18s/epoch - 117ms/step
# Epoch 137/700
#
# Epoch 137: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3999 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2873 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6415 - 17s/epoch - 113ms/step
# Epoch 138/700
#
# Epoch 138: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2818 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6387 - 17s/epoch - 115ms/step
# Epoch 139/700
#
# Epoch 139: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3997 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2734 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6345 - 17s/epoch - 113ms/step
# Epoch 140/700
#
# Epoch 140: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4022 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1989 - val_loss: 3.2888 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6422 - 17s/epoch - 114ms/step
# Epoch 141/700
#
# Epoch 141: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3997 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2128 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6042 - 17s/epoch - 115ms/step
# Epoch 142/700
#
# Epoch 142: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3994 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1975 - val_loss: 3.2157 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6056 - 18s/epoch - 116ms/step
# Epoch 143/700
#
# Epoch 143: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2696 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6326 - 18s/epoch - 117ms/step
# Epoch 144/700
#
# Epoch 144: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3993 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.2845 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6401 - 17s/epoch - 115ms/step
# Epoch 145/700
#
# Epoch 145: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4004 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.3077 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6517 - 18s/epoch - 119ms/step
# Epoch 146/700
#
# Epoch 146: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3990 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2542 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6249 - 17s/epoch - 115ms/step
# Epoch 147/700
#
# Epoch 147: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4003 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2548 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6252 - 17s/epoch - 114ms/step
# Epoch 148/700
#
# Epoch 148: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2233 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6095 - 18s/epoch - 116ms/step
# Epoch 149/700
#
# Epoch 149: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4018 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1987 - val_loss: 3.2466 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6211 - 18s/epoch - 117ms/step
# Epoch 150/700
#
# Epoch 150: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2101 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6029 - 17s/epoch - 116ms/step
# Epoch 151/700
#
# Epoch 151: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2518 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6237 - 17s/epoch - 115ms/step
# Epoch 152/700
#
# Epoch 152: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.3003 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6480 - 17s/epoch - 115ms/step
# Epoch 153/700
#
# Epoch 153: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3996 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2544 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6250 - 17s/epoch - 116ms/step
# Epoch 154/700
#
# Epoch 154: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3999 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.1986 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.5971 - 17s/epoch - 114ms/step
# Epoch 155/700
#
# Epoch 155: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4003 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2010 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.5983 - 17s/epoch - 114ms/step
# Epoch 156/700
#
# Epoch 156: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3990 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2941 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6449 - 17s/epoch - 112ms/step
# Epoch 157/700
#
# Epoch 157: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3990 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2290 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6123 - 17s/epoch - 115ms/step
# Epoch 158/700
#
# Epoch 158: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3990 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.2285 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6121 - 18s/epoch - 116ms/step
# Epoch 159/700
#
# Epoch 159: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3987 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2013 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.5985 - 17s/epoch - 114ms/step
# Epoch 160/700
#
# Epoch 160: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3997 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1977 - val_loss: 3.2439 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6198 - 17s/epoch - 113ms/step
# Epoch 161/700
#
# Epoch 161: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4002 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2413 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6185 - 17s/epoch - 112ms/step
# Epoch 162/700
#
# Epoch 162: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3994 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2589 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6273 - 17s/epoch - 115ms/step
# Epoch 163/700
#
# Epoch 163: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3992 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.3347 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6652 - 17s/epoch - 114ms/step
# Epoch 164/700
#
# Epoch 164: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3995 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.3099 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6528 - 17s/epoch - 114ms/step
# Epoch 165/700
#
# Epoch 165: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3994 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1975 - val_loss: 3.2306 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6131 - 17s/epoch - 115ms/step
# Epoch 166/700
#
# Epoch 166: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3989 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2238 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6098 - 18s/epoch - 116ms/step
# Epoch 167/700
#
# Epoch 167: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.4003 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2690 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6324 - 17s/epoch - 114ms/step
# Epoch 168/700
#
# Epoch 168: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3990 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.2211 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6084 - 17s/epoch - 114ms/step
# Epoch 169/700
#
# Epoch 169: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4001 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.3888 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6923 - 18s/epoch - 117ms/step
# Epoch 170/700
#
# Epoch 170: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4000 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2384 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6171 - 18s/epoch - 117ms/step
# Epoch 171/700
#
# Epoch 171: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3987 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2415 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6186 - 18s/epoch - 116ms/step
# Epoch 172/700
#
# Epoch 172: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3991 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.2391 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6174 - 18s/epoch - 119ms/step
# Epoch 173/700
#
# Epoch 173: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3987 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2275 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6116 - 18s/epoch - 116ms/step
# Epoch 174/700
#
# Epoch 174: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3987 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2097 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6027 - 17s/epoch - 116ms/step
# Epoch 175/700
#
# Epoch 175: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3986 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2084 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6021 - 17s/epoch - 116ms/step
# Epoch 176/700
#
# Epoch 176: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3993 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1975 - val_loss: 3.2165 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6061 - 17s/epoch - 115ms/step
# Epoch 177/700
#
# Epoch 177: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3998 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1978 - val_loss: 3.2371 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6164 - 18s/epoch - 116ms/step
# Epoch 178/700
#
# Epoch 178: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3994 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2972 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6465 - 18s/epoch - 117ms/step
# Epoch 179/700
#
# Epoch 179: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4006 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1982 - val_loss: 3.2092 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6025 - 18s/epoch - 117ms/step
# Epoch 180/700
#
# Epoch 180: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3988 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2784 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6371 - 18s/epoch - 119ms/step
# Epoch 181/700
#
# Epoch 181: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3984 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1971 - val_loss: 3.2387 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6173 - 17s/epoch - 115ms/step
# Epoch 182/700
#
# Epoch 182: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3988 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2435 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6196 - 17s/epoch - 113ms/step
# Epoch 183/700
#
# Epoch 183: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4000 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1979 - val_loss: 3.2198 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6078 - 18s/epoch - 117ms/step
# Epoch 184/700
#
# Epoch 184: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.4002 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1980 - val_loss: 3.2933 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6445 - 18s/epoch - 117ms/step
# Epoch 185/700
#
# Epoch 185: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3995 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1976 - val_loss: 3.2104 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6031 - 18s/epoch - 118ms/step
# Epoch 186/700
#
# Epoch 186: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3984 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1971 - val_loss: 3.2178 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6068 - 18s/epoch - 116ms/step
# Epoch 187/700
#
# Epoch 187: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3985 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2213 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6086 - 18s/epoch - 118ms/step
# Epoch 188/700
#
# Epoch 188: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3986 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.1953 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.5956 - 18s/epoch - 117ms/step
# Epoch 189/700
#
# Epoch 189: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3985 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2146 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6052 - 17s/epoch - 116ms/step
# Epoch 190/700
#
# Epoch 190: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3991 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1975 - val_loss: 3.2381 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6170 - 18s/epoch - 116ms/step
# Epoch 191/700
#
# Epoch 191: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3981 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1970 - val_loss: 3.2047 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6003 - 17s/epoch - 115ms/step
# Epoch 192/700
#
# Epoch 192: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 18s - loss: 0.3985 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1972 - val_loss: 3.2063 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6011 - 18s/epoch - 116ms/step
# Epoch 193/700
#
# Epoch 193: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3989 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1974 - val_loss: 3.2345 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6152 - 17s/epoch - 114ms/step
# Epoch 194/700
#
# Epoch 194: val_ws_predictor_loss did not improve from 1.57512
# 151/151 - 17s - loss: 0.3988 - gate_predictor_loss: 0.0000e+00 - ws_predictor_loss: 0.1973 - val_loss: 3.2482 - val_gate_predictor_loss: 0.0000e+00 - val_ws_predictor_loss: 1.6220 - 17s/epoch - 114ms/step
# Epoch 194: early stopping

# %% [markdown]
# ### Performance

# %%
saved_model = load_model('../saved_models/rnn_gtnp_1.h5',
                         custom_objects={'gate_loss':gate_loss, 
                                         'water_level_threshold':water_level_threshold,
                                         'GCNConv': GCNConv
                                        }
                        )
# Out:
# WARNING:tensorflow:Layer LSTM will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
start_time = time.perf_counter()

gate_pump_pred, ws_pred = saved_model.predict([test_X_mask, test_tws_reshape, test_adj_mat])

print(gate_pump_pred.shape)
print(ws_pred.shape)


end_time = time.perf_counter()
used_time = end_time - start_time
print(f"Usded time: {used_time} seconds")
# Out:
# 2023-08-12 17:20:41.506369: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 603/603 [==============================] - 12s 16ms/step
# (19268, 24, 7)
# (19268, 96)
# Usded time: 12.758216485846788 seconds

# %% [markdown]
# #### ws pred, gate pred

# %%
ws_pred_gate_pred_inv = ws_scaler.inverse_transform(ws_pred)
ws_pred_gate_pred_inv = ws_pred_gate_pred_inv.reshape((-1, K, 4))
ws_pred_gate_pred_inv.shape
# Out:
# (19268, 24, 4)

# %% [markdown]
# #### ws true, gate true

# %%
ws_true_gate_true = test_ws_y
ws_true_gate_true_inv = ws_scaler.inverse_transform(ws_true_gate_true)
ws_true_gate_true_inv = ws_true_gate_true_inv.reshape((-1, K, 4))
ws_true_gate_true_inv.shape
# Out:
# (19268, 24, 4)

# %% [markdown]
# #### ws pred, gate true

# %%
ws_predictor = load_model('../saved_models/WaLeF_gtn_p.h5', custom_objects={'GCNConv': GCNConv})

ws_pred_gate_true = ws_predictor.predict([test_cov, test_tws_reshape, test_adj_mat])
ws_pred_gate_true_inv = ws_scaler.inverse_transform(ws_pred_gate_true)
ws_pred_gate_true_inv = ws_pred_gate_true_inv.reshape((-1, 24, 4))
ws_pred_gate_true_inv.shape
# Out:
# WARNING:tensorflow:Layer LSTM will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 603/603 [==============================] - 2s 3ms/step
# (19268, 24, 4)

# %% [markdown]
# ### Upper threshould

# %%
upper_threshold = 3.5
t1 = 1

flood_threshold_t1(ws_true_gate_true_inv, t1, upper_threshold)
flood_threshold_t1(ws_pred_gate_true_inv, t1, upper_threshold)
flood_threshold_t1(ws_pred_gate_pred_inv, t1, upper_threshold)
# Out:
# S1, S25A, S25B, S26 time steps: 96, 96, 118, 117
# S1, S25A, S25B, S26 areas: 14.82, 15.22, 18, 20.13
# TOTAL time steps: 427; TOTAL areas: 68.61
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 85, 85, 96, 108
# S1, S25A, S25B, S26 areas: 11.5466, 12.1773, 13, 17.2181
# TOTAL time steps: 374; TOTAL areas: 54.3063
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 35, 40, 53, 83
# S1, S25A, S25B, S26 areas: 3.9751, 4.8576, 6, 10.2784
# TOTAL time steps: 211; TOTAL areas: 25.2836
# --------------------------------------------------

# %%
flood_threshold_t1(ws_true_gate_true_inv[7640-23:7680-23], t1, upper_threshold)
flood_threshold_t1(ws_pred_gate_true_inv[7640-23:7680-23], t1, upper_threshold)
flood_threshold_t1(ws_pred_gate_pred_inv[7640-23:7680-23], t1, upper_threshold)
# Out:
# S1, S25A, S25B, S26 time steps: 6, 5, 6, 6
# S1, S25A, S25B, S26 areas: 0.84, 0.72, 1, 1.0
# TOTAL time steps: 23; TOTAL areas: 3.62
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 6, 6, 5, 5
# S1, S25A, S25B, S26 areas: 0.6148, 0.6425, 1, 0.8663
# TOTAL time steps: 22; TOTAL areas: 3.0018
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 1, 2, 3, 2
# S1, S25A, S25B, S26 areas: 0.0744, 0.1286, 0, 0.2126
# TOTAL time steps: 8; TOTAL areas: 0.6338
# --------------------------------------------------

# %%
flood_threshold(ws_true_gate_true_inv, upper_threshold)
flood_threshold(ws_pred_gate_true_inv, upper_threshold)
flood_threshold(ws_pred_gate_pred_inv, upper_threshold)
# Out:
# time steps: 10248, areas: 1646.6399002075195
# time steps: 12130, areas: 2088.0380942821503
# time steps: 10070, areas: 1695.6511631011963

# %% [markdown]
# ### Lower threshold

# %%
lower_threshold = 0
t1 = 1

drought_threshold_t1(ws_true_gate_true_inv, t1, lower_threshold)
drought_threshold_t1(ws_pred_gate_true_inv, t1, lower_threshold)
drought_threshold_t1(ws_pred_gate_pred_inv, t1, lower_threshold)
# Out:
# S1, S25A, S25B, S26 time steps: 1346, 1341, 1229, 1250
# S1, S25A, S25B, S26 areas: -385.8, -383.38, -345.08, -350.84:
# TOTAL time steps: 5166; TOTAL areas: -1465.1
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 1390, 1427, 1282, 1476
# S1, S25A, S25B, S26 areas: -398.849, -392.0414, -350.2885, -429.5386:
# TOTAL time steps: 5575; TOTAL areas: -1570.7176
# --------------------------------------------------
# S1, S25A, S25B, S26 time steps: 251, 29, 26, 80
# S1, S25A, S25B, S26 areas: -41.0551, -3.8589, -2.5622, -10.9163:
# TOTAL time steps: 386; TOTAL areas: -58.3924
# --------------------------------------------------

# %%
lower_threshold = 0

drought_threshold(ws_true_gate_true_inv, lower_threshold)
drought_threshold(ws_pred_gate_true_inv, lower_threshold)
drought_threshold(ws_pred_gate_pred_inv, lower_threshold)
# Out:
# time steps: 124148, areas: 35182.6098122485
# time steps: 127126, areas: 34960.07284716559
# time steps: 12099, areas: 1981.021897669625
